# %% [markdown]
# We need to create a list of chapters of the book of mormon. Each chapter needs to be a dictionary with the following attributes:
# - id
# - title
# - file

# %%
ROOT_PATH = r'bom_text\the_bom'

# iterate through each directory in root path
# for each file, create a new dictionary object with id, title, and file path (in html path format)

# %%
# Take the list of dictionaries and print in a javascript pattern that works
